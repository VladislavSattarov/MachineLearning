# %% [markdown]
# Текстовое описание датасета
#
# Этот набор данных содержит 1294757 описаний объявлений с автомобилями.
#
# Мы видим, что столбцы (признаки) имеют имена
#
#  0   brand                 Марка автомобиля
#  1   name                  Модель автомобиля
#  2   bodyType              Тип кузова
#  3   color                 Цвет
#  4   fuelType              Тип топлива
#  5   year                  Год выпуска
#  6   mileage               Пробег
#  7   transmission          Коробка
#  8   power                 Мощность
#  9   price                 Цена
#  10  vehicleConfiguration  Комплектация
#  11  engineName            Название двигателя
#  12  engineDisplacement    Тип и объем двигателя
#  13  date                  Дата публикации объявления
#  14  location              Место нахождения автомобиля
#  15  link                  Ссылка на объявление
#  16  description           Комментарий в объявлении
#  17  parse_date            Дата получения данных
#
# Признаки brand, name, bodyType, color, fuelType, transmission, vehicleConfiguration, engineName, engineDisplacement, location - номинальные (категориальные).
#
# Признаки year, mileage, power, price - количественные.
#
# Остальные признаки являются текстовыми.
#
# Требуется оценить стоимость автомобиля по заданным признакам. То есть предсказать, какая будет рыночная цена.
#
# Это задача регрессии.

# %%
import numpy as np              # Одномерные и многомерные массивы (array)
import pandas as pd             # Таблицы и временные ряды (dataframe, series)
import matplotlib.pyplot as plt # Научная графика
import seaborn as sns           # Еще больше красивой графики для визуализации данных
import sklearn                  # Алгоритмы машинного обучения
from threading import Thread

# %% [markdown]
# Прочтем данные:

# %%
url = "C:/Users/Vladislav/Documents/archive/all_regions.csv"
data_raw = pd.read_csv(url)

# %%
data_raw.shape
# Out:
# (1294757, 18)

# %%
data_raw
# Out:
#               brand           name       bodyType        color fuelType  \
# 0        Volkswagen           Golf  Хэтчбек 5 дв.  Серебристый   Бензин
# 1              Лада       1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин
# 2            Toyota       Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин
# 3              Лада         Гранта        Лифтбек        Серый   Бензин
# 4              Лада    Нива Легенд     Джип 3 дв.      Зеленый   Бензин
# ...             ...            ...            ...          ...      ...
# 1294752         BMW             X1     Джип 5 дв.        Серый   Дизель
# 1294753        Лада           2105          Седан        Белый   Бензин
# 1294754      Toyota          Camry          Седан        Серый   Бензин
# 1294755        Лада  4x4 2121 Нива     Джип 3 дв.        Белый   Бензин
# 1294756        Лада  4x4 2121 Нива     Джип 3 дв.        Белый   Бензин
#
#            year   mileage transmission  power    price vehicleConfiguration  \
# 0           NaN  240000.0     Механика  101.0   280000                  NaN
# 1        1996.0   37000.0     Механика   33.0    95000         0.6 MT 11113
# 2        2002.0  295000.0         АКПП   87.0   380000                1.3 J
# 3        2018.0   16000.0     Механика  106.0   795000       1.6 MT Comfort
# 4           NaN       NaN     Механика   83.0  1022900                  NaN
# ...         ...       ...          ...    ...      ...                  ...
# 1294752     NaN  275000.0         АКПП  177.0  1000000                  NaN
# 1294753  1985.0  300000.0     Механика   64.0   165000        1.3 MT5 21050
# 1294754  2020.0   32000.0         АКПП  202.0  3100000            2.5 AT SE
# 1294755  1995.0  354000.0     Механика   79.0   298000               1.7 MT
# 1294756  1995.0  354000.0     Механика   79.0   320000               1.7 MT
#
#         engineName engineDisplacement                 date      location  \
# 0              NaN                NaN  2023-04-02 00:00:00        Майкоп
# 1        ВАЗ-11113            0.7 LTR  2023-04-02 00:00:00        Майкоп
# 2           2NZ-FE            1.3 LTR  2023-04-02 00:00:00        Майкоп
# 3        ВАЗ-21127            1.6 LTR  2023-04-02 00:00:00        Майкоп
# 4              NaN                NaN  2023-04-02 00:00:00   Яблоновский
# ...            ...                ...                  ...           ...
# 1294752        NaN                NaN  2023-06-01 00:00:00      Черкесск
# 1294753   ВАЗ-2105            1.3 LTR  2023-06-01 00:00:00  Усть-Джегута
# 1294754   A25A-FKS            2.5 LTR  2023-06-01 00:00:00      Черкесск
# 1294755  ВАЗ-21213            1.7 LTR  2023-06-01 00:00:00      Черкесск
# 1294756  ВАЗ-21213            1.7 LTR  2023-06-01 00:00:00      Черкесск
#
#                                                       link  \
# 0        https://maykop.drom.ru/volkswagen/golf/5001300...
# 1            https://maykop.drom.ru/lada/oka/50378140.html
# 2        https://maykop.drom.ru/toyota/funcargo/5037751...
# 3         https://maykop.drom.ru/lada/granta/50382492.html
# 4        https://yablonovskiy.drom.ru/lada/niva_legend/...
# ...                                                    ...
# 1294752     https://cherkessk.drom.ru/bmw/x1/51154874.html
# 1294753  https://ust-dzheguta.drom.ru/lada/2105/5114990...
# 1294754  https://cherkessk.drom.ru/toyota/camry/5115596...
# 1294755  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
# 1294756  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
#
#                                                description  \
# 0        101 л.с. люк не течёт. Документы в порядке. Со...
# 1        Ваз Ока Год: 2003 Цвет: Баклажан, в ПТС так и ...
# 2        ХОРОШЕЕ СОСТОЯНИЕ. замена комплекта грм и помп...
# 3        Автомобиль в отличном техническом состоянии, н...
# 4        Модель: Нива Легенд Комплектация: LADA (ВАЗ) N...
# ...                                                    ...
# 1294752  Продам автомобиль BMW X1 2d в идеальном состоя...
# 1294753  продаю автомобиль изо не надобности автомобиль...
# 1294754  Америнка,в отличном состоянии,любые проверки. ...
# 1294755  Нива в хорошем состоянии, без гнили, лонжероны...
# 1294756  Нива в хорошем состоянии, без гнили, лонжероны...
#
#                   parse_date
# 0        2023-05-02 01:00:00
# 1        2023-05-02 20:00:00
# 2        2023-05-02 20:00:00
# 3        2023-05-02 23:00:00
# 4        2023-05-02 20:00:00
# ...                      ...
# 1294752  2023-06-01 21:00:00
# 1294753  2023-06-01 13:00:00
# 1294754  2023-06-01 20:00:00
# 1294755  2023-06-01 23:00:00
# 1294756  2023-06-01 21:00:00
#
# [1294757 rows x 18 columns]

# %%
data_raw.head(15)
# Out:
#          brand         name       bodyType        color fuelType    year  \
# 0   Volkswagen         Golf  Хэтчбек 5 дв.  Серебристый   Бензин     NaN
# 1         Лада     1111 Ока  Хэтчбек 3 дв.   Фиолетовый   Бензин  1996.0
# 2       Toyota     Funcargo  Хэтчбек 5 дв.  Серебристый   Бензин  2002.0
# 3         Лада       Гранта        Лифтбек        Серый   Бензин  2018.0
# 4         Лада  Нива Легенд     Джип 3 дв.      Зеленый   Бензин     NaN
# 5         Лада       Гранта        Лифтбек       Черный   Бензин     NaN
# 6         Лада       Гранта        Лифтбек       Черный   Бензин     NaN
# 7         Лада  Нива Легенд     Джип 3 дв.        Белый   Бензин     NaN
# 8         Лада       Гранта        Лифтбек       Черный   Бензин     NaN
# 9    Chevrolet         Niva     Джип 5 дв.      Зеленый   Бензин  2002.0
# 10        Audi           A8          Седан       Черный   Дизель     NaN
# 11        Лада       Гранта          Седан        Белый   Бензин     NaN
# 12        Лада  2114 Самара  Хэтчбек 5 дв.       Черный   Бензин  2007.0
# 13        Лада       Гранта          Седан        Белый   Бензин     NaN
# 14        Лада       Гранта          Седан        Белый   Бензин     NaN
#
#      mileage transmission  power    price vehicleConfiguration engineName  \
# 0   240000.0     Механика  101.0   280000                  NaN        NaN
# 1    37000.0     Механика   33.0    95000         0.6 MT 11113  ВАЗ-11113
# 2   295000.0         АКПП   87.0   380000                1.3 J     2NZ-FE
# 3    16000.0     Механика  106.0   795000       1.6 MT Comfort  ВАЗ-21127
# 4        NaN     Механика   83.0  1022900                  NaN        NaN
# 5        NaN     Механика   90.0   966900                  NaN        NaN
# 6        NaN     Механика   90.0   992900                  NaN        NaN
# 7        NaN     Механика   83.0   972900                  NaN        NaN
# 8        NaN     Механика   90.0   942900                  NaN        NaN
# 9   220000.0     Механика   80.0   450000             1.7 MT L   ВАЗ-2123
# 10   27000.0         АКПП  286.0  7090000                  NaN        NaN
# 11       NaN     Механика   90.0   969900                  NaN        NaN
# 12  185000.0     Механика   81.0   120000  1.6 MT 21144-22-010  ВАЗ-11183
# 13       NaN     Механика   90.0   969900                  NaN        NaN
# 14       NaN     Механика   90.0   947900                  NaN        NaN
#
#    engineDisplacement                 date     location  \
# 0                 NaN  2023-04-02 00:00:00       Майкоп
# 1             0.7 LTR  2023-04-02 00:00:00       Майкоп
# 2             1.3 LTR  2023-04-02 00:00:00       Майкоп
# 3             1.6 LTR  2023-04-02 00:00:00       Майкоп
# 4                 NaN  2023-04-02 00:00:00  Яблоновский
# 5                 NaN  2023-04-02 00:00:00       Майкоп
# 6                 NaN  2023-04-02 00:00:00       Майкоп
# 7                 NaN  2023-04-02 00:00:00       Майкоп
# 8                 NaN  2023-04-02 00:00:00       Майкоп
# 9             1.7 LTR  2023-04-03 00:00:00       Майкоп
# 10                NaN  2023-04-03 00:00:00       Майкоп
# 11                NaN  2023-04-03 00:00:00  Яблоновский
# 12            1.6 LTR  2023-04-03 00:00:00       Майкоп
# 13                NaN  2023-04-03 00:00:00  Яблоновский
# 14                NaN  2023-04-03 00:00:00  Яблоновский
#
#                                                  link  \
# 0   https://maykop.drom.ru/volkswagen/golf/5001300...
# 1       https://maykop.drom.ru/lada/oka/50378140.html
# 2   https://maykop.drom.ru/toyota/funcargo/5037751...
# 3    https://maykop.drom.ru/lada/granta/50382492.html
# 4   https://yablonovskiy.drom.ru/lada/niva_legend/...
# 5    https://maykop.drom.ru/lada/granta/50007643.html
# 1294755            1.7 LTR  2023-06-01 00:00:00      Черкесск
# 1294756            1.7 LTR  2023-06-01 00:00:00      Черкесск
#
#                                                       link  \
# 1294752     https://cherkessk.drom.ru/bmw/x1/51154874.html
# 1294753  https://ust-dzheguta.drom.ru/lada/2105/5114990...
# 1294754  https://cherkessk.drom.ru/toyota/camry/5115596...
# 1294755  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
# 1294756  https://cherkessk.drom.ru/lada/2121_4x4_niva/5...
#
#                                                description  \
# 1294752  Продам автомобиль BMW X1 2d в идеальном состоя...
# 1294753  продаю автомобиль изо не надобности автомобиль...
# 1294754  Америнка,в отличном состоянии,любые проверки. ...
# 1294755  Нива в хорошем состоянии, без гнили, лонжероны...
# 1294756  Нива в хорошем состоянии, без гнили, лонжероны...
#
#                   parse_date
# 1294752  2023-06-01 21:00:00
# 1294753  2023-06-01 13:00:00
# 1294754  2023-06-01 20:00:00
# 1294755  2023-06-01 23:00:00
# 1294756  2023-06-01 21:00:00

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294757 entries, 0 to 1294756
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   brand                 1294757 non-null  object
#  1   name                  1294757 non-null  object
#  2   bodyType              1294757 non-null  object
#  3   color                 1257029 non-null  object
#  4   fuelType              1289815 non-null  object
#  5   year                  724644 non-null   float64
#  6   mileage               771799 non-null   float64
#  7   transmission          1289563 non-null  object
#  8   power                 1273353 non-null  float64
#  9   price                 1294757 non-null  int64
#  10  vehicleConfiguration  724647 non-null   object
#  11  engineName            720976 non-null   object
#  12  engineDisplacement    717625 non-null   object
#  13  date                  1294757 non-null  object
#  14  location              1294757 non-null  object
#  15  link                  1294757 non-null  object
#  16  description           1254405 non-null  object
#  17  parse_date            1294757 non-null  object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 177.8+ MB

# %% [markdown]
# Найдем признаки с категориальным типом и преобразуем их

# %%
data_raw['brand'] = data_raw['brand'].astype('category')
data_raw['bodyType'] = data_raw['bodyType'].astype('category')
data_raw['color'] = data_raw['color'].astype('category')
data_raw['fuelType'] = data_raw['fuelType'].astype('category')
data_raw['transmission'] = data_raw['transmission'].astype('category')
data_raw['engineName'] = data_raw['engineName'].astype('category')
data_raw['vehicleConfiguration'] = data_raw['vehicleConfiguration'].astype('category')
data_raw['location'] = data_raw['location'].astype('category')
data_raw['engineDisplacement'] = data_raw['engineDisplacement'].astype('category')
data_raw['name'] = data_raw['name'].astype('category')

# %%
data_raw['brand'].dtype
# Out:
# CategoricalDtype(categories=['AC', 'AITO', 'Acura', 'Alfa Romeo', 'Alpina', 'Aro', 'Asia',
#                   'Aston Martin', 'Audi', 'Avatr',
#                   ...
#                   'ЗАЗ', 'ЗИЛ', 'ЗиС', 'ИЖ', 'Лада', 'ЛуАЗ', 'Москвич',
#                   'Прочие авто', 'ТагАЗ', 'УАЗ'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['bodyType'].dtype
# Out:
# CategoricalDtype(categories=['Джип 3 дв.', 'Джип 5 дв.', 'Купе', 'Лифтбек', 'Минивэн',
#                   'Открытый', 'Пикап', 'Седан', 'Универсал', 'Хэтчбек 3 дв.',
#                   'Хэтчбек 5 дв.'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['color'].dtype
# Out:
# CategoricalDtype(categories=['Бежевый', 'Белый', 'Бордовый', 'Голубой', 'Желтый',
#                   'Зеленый', 'Золотистый', 'Коричневый', 'Красный',
#                   'Оранжевый', 'Розовый', 'Серебристый', 'Серый', 'Синий',
#                   'Фиолетовый', 'Черный'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['fuelType'].dtype
# Out:
# CategoricalDtype(categories=['Бензин', 'Дизель', 'Электро'], ordered=False, categories_dtype=object)

# %%
data_raw['transmission'].dtype
# Out:
# CategoricalDtype(categories=['АКПП', 'Автомат', 'Вариатор', 'Механика', 'Робот'], ordered=False, categories_dtype=object)

# %%
data_raw['engineDisplacement'].dtype
# Out:
# CategoricalDtype(categories=['0.5 LTR', '0.6 LTR', '0.7 LTR', '0.8 LTR', '0.9 LTR',
#                   '1.0 LTR', '1.1 LTR', '1.2 LTR', '1.3 LTR', '1.4 LTR',
#                   '1.5 LTR', '1.6 LTR', '1.7 LTR', '1.8 LTR', '1.9 LTR',
#                   '2.0 LTR', '2.1 LTR', '2.2 LTR', '2.3 LTR', '2.4 LTR',
#                   '2.5 LTR', '2.6 LTR', '2.7 LTR', '2.8 LTR', '2.9 LTR',
#                   '3.0 LTR', '3.1 LTR', '3.2 LTR', '3.3 LTR', '3.4 LTR',
#                   '3.5 LTR', '3.6 LTR', '3.7 LTR', '3.8 LTR', '3.9 LTR',
#                   '4.0 LTR', '4.1 LTR', '4.2 LTR', '4.3 LTR', '4.4 LTR',
#                   '4.5 LTR', '4.6 LTR', '4.7 LTR', '4.8 LTR', '4.9 LTR',
#                   '5.0 LTR', '5.2 LTR', '5.3 LTR', '5.4 LTR', '5.5 LTR',
#                   '5.6 LTR', '5.7 LTR', '5.8 LTR', '5.9 LTR', '6.0 LTR',
#                   '6.1 LTR', '6.2 LTR', '6.3 LTR', '6.4 LTR', '6.5 LTR',
#                   '6.6 LTR', '6.7 LTR', '6.8 LTR', '7.0 LTR', '7.6 LTR',
#                   '8.0 LTR', '8.1 LTR', '8.3 LTR', '8.4 LTR'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['name'].dtype
# Out:
# CategoricalDtype(categories=['001', '009', '05', '09', '1-Series', '100', '1007', '100NX',
#                   '107', '11',
#                   ...
#                   'Таврия', 'ТагАЗ', 'Тагер', 'Форца', 'Х-Кросс 5', 'Х-рей',
#                   'Х-рей Кросс', 'Хантер', 'Чайка', 'Шанс'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['engineName'].dtype
# Out:
# CategoricalDtype(categories=[' \tMDC.BE', ' 2GR-FSE', ' A16LET', ' BM15L', '1.5 Ecoboost',
#                   '1.6 Ecoboost', '10HM', '10P, 15P', '10S', '12A',
#                   ...
#                   'УЗАМ-412Э', 'УМЗ 4218', 'УМЗ 4218.10', 'УМЗ-414',
#                   'УМЗ-4178', 'УМЗ-4178.10', 'УМЗ-421.10', 'УМЗ-4213.10',
#                   'УМЗ-4218', 'УМЗ-4218.10'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['vehicleConfiguration'].dtype
# Out:
# CategoricalDtype(categories=[' 1.0 CILQ G Package SAIII', ' 1.0 CILQ G Package SAIII 4WD',
#                   ' 1.0 CILQ SAIII', ' 1.0 Custom G', ' 1.0 Custom G ',
#                   ' 1.0 Custom G 4WD', ' 1.0 Custom G Limited II SAIII',
#                   ' 1.0 Custom G Limited II SAIII 4WD',
#                   ' 1.0 Custom G Limited SAIII',
#                   ' 1.0 Custom G Limited SAIII 4WD',
#                   ...
#                   'xDrive50 Suite Sport', 'xDriveM50i', 'ГАЗ-21Р', 'ГАЗ-22',
#                   'ГАЗ-М-21В', 'ГАЗ-М-21Г', 'ГАЗ-М-21И', 'ГАЗ-М-21Л',
#                   'Т21С15-МТ2', 'Х5 М'],
# , ordered=False, categories_dtype=object)

# %%
data_raw['location'].dtype
# Out:
# CategoricalDtype(categories=['1-го отделения совхоза Масловский', 'Абадзехская', 'Абаза',
#                   'Абакан', 'Абан', 'Абатское', 'Абдулино', 'Абинск',
#                   'Абрау-Дюрсо', 'Авдон',
#                   ...
#                   'Яшкино', 'Яшкуль', 'Яя', 'дачный Мочище', 'им. Бабушкина',
#                   'им. Карла Либкнехта', 'им. Свердлова', 'им. Тельмана',
#                   'имени 9 Января', 'совхоза Раменское'],
# , ordered=False, categories_dtype=object)

# %% [markdown]
# 2. Визуализируем, анализируем, боремся с выбросами (outliers)

# %% [markdown]
# Выведем статистику по всем признакам датасета

# %%
data_raw.describe()
# Out:
#                 year         mileage         power         price
# count  724644.000000   771799.000000  1.273353e+06  1.294757e+06
# mean     2009.684535   154893.397115  1.415560e+02  1.444358e+06
# std         9.367108   100738.336936  6.563943e+01  1.970257e+06
# min      1936.000000     1000.000000  1.000000e+00  2.700000e+02
# 25%      2003.000000    82000.000000  9.800000e+01  4.250000e+05
# 50%      2011.000000   144000.000000  1.280000e+02  8.700000e+05
# 75%      2017.000000   211000.000000  1.630000e+02  1.765000e+06
# max      2023.000000  1000000.000000  1.000000e+03  1.500000e+08

# %%
data_raw.describe(include=['category'])
# Out:
#           brand     name    bodyType    color fuelType transmission  \
# count   1294757  1294757     1294757  1257029  1289815      1289563
# unique      160     2223          11       16        3            5
# top      Toyota   Гранта  Джип 5 дв.    Белый   Бензин         АКПП
# freq     265598    33536      427108   321170  1173467       511032
#
#        vehicleConfiguration engineName engineDisplacement location
# count                724647     720976             717625  1294757
# unique                26874       4219                 69     3400
# top        1.5 CVT Стандарт     1NZ-FE            1.5 LTR   Москва
# freq                   5262      17826             139732   115771

# %% [markdown]
# Понятно, что цена автомобиля в первую очередь зависит от его года выпуска. Построим поэтому диаграмму рассеивания для двух признаков: price и year.

# %%
data_raw.plot(kind='scatter', x='year', y='price')
pass

# %% [markdown]
# Теперь постороим диаграмму рассеивания для двух признаков: price и power.

# %%
data_raw.plot(kind='scatter', x='power', y='price')
pass

# %%
Теперь постороим диаграмму рассеивания для двух признаков: price и mileage.

# %%
data_raw.plot(kind='scatter', x='mileage', y='price')
pass

# %% [markdown]
# Построим все диаграммы рассеивания:

# %%
pd.plotting.scatter_matrix(data_raw, figsize = (10, 8))
pass

# %% [markdown]
# Выведем матрицу корреляции датасета

# %%
corr_mat = data_raw.corr(numeric_only=True)
corr_mat
# Out:
#              year   mileage     power     price
# year     1.000000 -0.513488  0.202671  0.494491
# mileage -0.513488  1.000000 -0.022772 -0.365223
# power    0.202671 -0.022772  1.000000  0.608741
# price    0.494491 -0.365223  0.608741  1.000000

# %% [markdown]
# Визуализируем:

# %%
sns.heatmap(corr_mat, square=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(corr_mat, square=True, annot=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm')
pass

# %% [markdown]
# Видно, что из всех значимых признаков больше всех прослеживается корреляция цены с признаком power (мощность)

# %% [markdown]
# Выведем коэффициенты корреляции, большие заданного значения:

# %%
corr_mat > 0.4
# Out:
#           year  mileage  power  price
# year      True    False  False   True
# mileage  False     True  False  False
# power    False    False   True   True
# price     True    False   True   True

# %%
data_raw[data_raw['price'] > 50000000]
# Out:
#                  brand        name    bodyType       color fuelType    year  \
# 416347          Toyota       Crown       Седан       Белый   Бензин  1989.0
# 758048     Lamborghini        Urus  Джип 5 дв.      Желтый   Бензин  2022.0
# 869610             BMW    5-Series       Седан      Черный   Бензин  1994.0
# 874256             Kia      Mohave  Джип 5 дв.       Белый   Дизель     NaN
# 1081628    Rolls-Royce     Phantom       Седан  Фиолетовый   Бензин     NaN
# 1084793  Mercedes-Benz     S-Class       Седан         NaN   Бензин  2021.0
# 1097359  Mercedes-Benz     S-Class       Седан      Черный   Бензин     NaN
# 1101683        Bugatti      Veyron        Купе         NaN   Бензин  2005.0
# 1103429  Mercedes-Benz     G-Class  Джип 5 дв.     Зеленый   Бензин     NaN
# 1103939    Rolls-Royce    Cullinan  Джип 5 дв.         NaN   Бензин  2018.0
# 1118785        Ferrari  Purosangue  Джип 5 дв.         NaN   Бензин  2023.0
# 1118787        Ferrari  Purosangue  Джип 5 дв.         NaN   Бензин  2023.0
# 1119647    Rolls-Royce       Ghost       Седан      Черный   Бензин  2020.0
# 1119651  Mercedes-Benz     G-Class  Джип 5 дв.      Черный   Бензин  2020.0
# 1119652  Mercedes-Benz     S-Class       Седан      Черный   Бензин  2021.0
# 1119653    Rolls-Royce       Ghost       Седан      Черный   Бензин  2020.0
# 1119666    Rolls-Royce    Cullinan  Джип 5 дв.         NaN   Бензин  2018.0
# 1119720  Mercedes-Benz     S-Class       Седан         NaN   Бензин     NaN
# 1142171  Mercedes-Benz     S-Class       Седан      Черный   Бензин     NaN
# 1146458  Mercedes-Benz     G-Class  Джип 5 дв.     Зеленый   Бензин     NaN
# 1153677  Mercedes-Benz     S-Class       Седан      Черный   Бензин     NaN
# 1189398       NaN        Робот  830.0   51500000
# 1189405       NaN         АКПП  563.0   67800000
# 1189431       NaN         АКПП  563.0   59999999
# 1189437       NaN         АКПП  585.0   54999999
# 1189439       NaN         АКПП  585.0   59999999
# 1193347       NaN      Автомат  600.0   59800000
# 1222512    2000.0      Автомат    NaN   99999999
# 1274558   17000.0     Механика   55.0   69000000
#
#                  vehicleConfiguration      engineName engineDisplacement  \
# 416347      3.0 royal saloon (column)           7M-GE            3.0 LTR
# 758048                       4.0 AT S             NaN                NaN
# 869610                        518i MT          M43B18            1.8 LTR
# 874256                            NaN             NaN                NaN
# 1081628                           NaN             NaN                NaN
# 1084793  Mercedes-Maybach S680 4MATIC   M 279 E 60 AL            6.0 LTR
# 1097359                           NaN             NaN                NaN
# 1101683           8.0 DSG Veyron 16.4             NaN                NaN
# 1103429                           NaN             NaN                NaN
# 1103939                    6.8 AT 4WD          N74B68            6.7 LTR
# 1118785                       6.5 AMT         F140 IA            6.5 LTR
# 1118787                       6.5 AMT         F140 IA            6.5 LTR
# 1119647                        6.8 AT          N74B68            6.8 LTR
# 1119651                      G 63 AMG  M 177 DE 40 AL            4.0 LTR
# 1119652  Mercedes-Maybach S680 4MATIC   M 279 E 60 AL            6.0 LTR
# 1119653                        6.8 AT          N74B68            6.8 LTR
# 1119666                    6.8 AT 4WD          N74B68            6.7 LTR
# 1119720                           NaN             NaN                NaN
# 1142171                           NaN             NaN                NaN
# 1146458                           NaN             NaN                NaN
# 1153677                           NaN             NaN                NaN
# 1155644                           NaN             NaN                NaN
# 1155646                           NaN             NaN                NaN
# 1156603                           NaN             NaN                NaN
# 1160256                    6.8 AT 4WD          N74B68            6.7 LTR
# 1187457                           NaN             NaN                NaN
# 1189187                           NaN             NaN                NaN
# 1189197                         S 600   M 279 E 60 AL            6.0 LTR
# 1189198                    6.8 AT 4WD          N74B68            6.7 LTR
# 1189292                      G 65 AMG   M 275 E 60 AL            6.0 LTR
# 1189384                           NaN             NaN                NaN
# 1189387                      G 63 AMG  M 177 DE 40 AL            4.0 LTR
# 1189398        6.5 AMT Competizione A         F140 GA            6.5 LTR
# 1189405                           NaN             NaN                NaN
# 1189431                           NaN             NaN                NaN
# 1189437                      G 63 AMG  M 177 DE 40 AL            4.0 LTR
# 1189439                      G 63 AMG  M 177 DE 40 AL            4.0 LTR
# 1193347                           NaN             NaN                NaN
# 1222512                           NaN             NaN                NaN
# 1274558                        2.1 MT          ГАЗ-69            2.1 LTR
#
#                         date              location  \
# 416347   2023-05-19 00:00:00  Комсомольск-на-Амуре
# 758048   2023-05-08 00:00:00           Новосибирск
# 869610   2023-05-08 00:00:00                Суксун
# 874256   2023-05-30 00:00:00                 Пермь
# 1081628  2023-05-01 00:00:00                Москва
# 1084793  2023-05-02 00:00:00                Москва
# 1097359  2023-05-08 00:00:00                Москва
# 1101683  2023-05-11 00:00:00                Москва
# 1103429  2023-05-11 00:00:00                Москва
# 1103939  2023-05-12 00:00:00                Москва
# 1118785  2023-05-23 00:00:00                Москва
# 1118787  2023-05-23 00:00:00                Москва
# 419140        NaN                NaN  2023-05-24 00:00:00    Хабаровск
# 681645        NaN                NaN  2023-06-21 00:00:00     Кемерово
# 923521        NaN                NaN  2023-04-29 00:00:00  Берёзовский
#
#                                                      link  \
# 41870   https://razdolnoe-krym.drom.ru/other/rus/50946...
# 62317   https://chulman.drom.ru/lada/2121_4x4_niva/464...
# 66873   https://neryungri.drom.ru/other/rus/51066857.html
# 135657  https://yazykovo-ufa.drom.ru/lada/2114/5044906...
# 400925  https://stavropol.drom.ru/nissan/gt-r/46844974...
# 419140  https://habarovsk.drom.ru/toyota/cresta/489747...
# 681645  https://kemerovo.drom.ru/ssang_yong/istana/506...
# 923521  https://berezovskiy-sverd.drom.ru/lada/priora/...
#
#                                               description           parse_date
# 41870   Продам Газель в отличном состоянии. На газу, г...  2023-05-20 04:00:00
# 62317   Продам ниву. Не гнилая, свеже крашена,есть кот...  2023-05-15 18:00:00
# 66873   Нужно сделать электрику, настроить трамблер пр...  2023-05-29 21:00:00
# 135657  Продаётся ваз 2114 в хорошем состоянии не биты...  2023-06-08 14:00:00
# 400925  Расчётная мощность 1000 л/с Пожалуйста не срав...  2023-06-21 17:00:00
# 419140  СОБСТВЕННИК* * 15 лет в моих руках . * 180 ЛС ...  2023-05-25 08:00:00
# 681645                             хорошие состояния на 4  2023-06-21 15:00:00
# 923521  ОДИН СОБСТВЕНИК, МАКСИМАЛЬНАЯ КОМПЛЕКТАЦИЯ, ОР...  2023-05-02 04:00:00

# %% [markdown]
# Обнаружим выбросы:

# %%
data_raw['price'].plot(kind='box')
pass

# %%
data_raw['price'].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
# 0.005       47000.0
# 0.010       59000.0
# 0.050      120000.0
# 0.100      195000.0
# 0.500      870000.0
# 0.900     3190000.0
# 0.950     4270900.0
# 0.990     9000000.0
# 0.995    12800000.0
# Name: price, dtype: float64

# %%
data_raw['mileage'].plot(kind='box')
pass

# %%
data_raw['power'].plot(kind='box')
pass

# %%
data_raw['price'].quantile([0.0005,.01,.05,.1,.5,.9,.95,.99,.9999])
# Out:
# 0.0005       26189.0
# 0.0100       59000.0
# 0.0500      120000.0
# 0.1000      195000.0
# 0.5000      870000.0
# 0.9000     3190000.0
# 0.9500     4270900.0
# 0.9900     9000000.0
# 0.9999    35000786.6
# Name: price, dtype: float64

# %% [markdown]
# Удалим все строки таблицы, в которых 'price' выходят за пределы квантилей 0.0005, 0.9995.

# %%
rows_to_drop = data_raw[
    (data_raw['price'] < data_raw['price'].quantile(0.0005)) | (data_raw['price'] > data_raw['price'].quantile(0.9999))].index
data = data_raw.drop(rows_to_drop)
data.shape
# Out:
# (1293979, 18)

# %%
data['price'].plot(kind='box')
pass

# %%
data.plot(kind='scatter', x='year', y='price', alpha=.01)
pass

# %%
data.plot(kind='scatter', x='power', y='price', alpha=.01)
pass

# %%
data.plot(kind='scatter', x='mileage', y='price', alpha=.01)
pass

# %%
data['bodyType'].value_counts().index
# Out:
# CategoricalIndex(['Джип 5 дв.', 'Седан', 'Хэтчбек 5 дв.', 'Минивэн',
#                   'Универсал', 'Лифтбек', 'Джип 3 дв.', 'Хэтчбек 3 дв.',
#                   'Пикап', 'Купе', 'Открытый'],
#                  categories=['Джип 3 дв.', 'Джип 5 дв.', 'Купе', 'Лифтбек', ..., 'Седан', 'Универсал', 'Хэтчбек 3 дв.', 'Хэтчбек 5 дв.'], ordered=False, dtype='category', name='bodyType')

# %%
sns.pairplot(data.sample(1000), hue='bodyType', diag_kind='hist')
pass

# %%
sns.pairplot(data.sample(1000), hue='transmission', diag_kind='hist')
pass

# %% [markdown]
# Обработаем пропущенные значения:

# %%
data.isnull().sum()
# Out:
# brand                        0
# name                         0
# bodyType                     0
# color                    37644
# fuelType                  4926
# year                    569787
# mileage                 522643
# transmission              5175
# power                    21377
# price                        0
# vehicleConfiguration    569784
# engineName              573450
# engineDisplacement      576801
# date                         0
# location                     0
# link                         0
# description              40304
# parse_date                   0
# dtype: int64

# %% [markdown]
# Информация в столбце description написана "от руки", поэтому большого значения не будет иметь. Его следует удалить.
# Некоторые признаки имеют большое количество пропущенных значений, особенно признаки engineName, vehicleConfiguration. Кроме того, признак engineDisplacement частично отражает суть этих признака. Поэтому для оптимальной обработки датасета исключим признаки engineName, vehicleConfiguration из таблицы.

# %%
data = data.drop(["engineName", "vehicleConfiguration", "description", ], axis = 1)

# %%
data.isnull().sum()
# Out:
# brand                      0
# name                       0
# bodyType                   0
# color                  37644
# fuelType                4926
# year                  569787
# mileage               522643
# transmission            5175
# power                  21377
# price                      0
# engineDisplacement    576801
# date                       0
# location                   0
# link                       0
# parse_date                 0
# dtype: int64

# %% [markdown]
# Заполним медианами пропущенные значения в столбцах, соответствующих количественным признакам:

# %%
from sklearn.impute import SimpleImputer
imp_num = SimpleImputer(missing_values=np.nan, strategy='median')
imp_num.fit(data[['year', 'mileage', 'power']])
# Out:
# SimpleImputer(strategy='median')

# %%
data[['year', 'mileage', 'power']] = imp_num.transform(data[['year', 'mileage', 'power']])

# %%
data.isnull().sum()
# Out:
# brand                      0
# name                       0
# bodyType                   0
# color                  37644
# fuelType                4926
# year                       0
# mileage                    0
# transmission            5175
# power                      0
# price                      0
# engineDisplacement    576801
# date                       0
# location                   0
# link                       0
# parse_date                 0
# dtype: int64

# %% [markdown]
# Заполним наиболее частыми значения в столбцах, соответствующих категориальным признакам/ Еще можно ввести новый признак - индикатор пропущенного значения (легко сделать при бинаризации ниже).

# %%
from sklearn.impute import SimpleImputer
imp_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_cat.fit(data[['color', 'fuelType', 'transmission', 'engineDisplacement']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
data[['color', 'fuelType', 'transmission', 'engineDisplacement']] = imp_cat.transform(data[['color', 'fuelType', 'transmission', 'engineDisplacement']])

# %%
data.isnull().sum()
# Out:
# brand                 0
# name                  0
# bodyType              0
# color                 0
# fuelType              0
# year                  0
# mileage               0
# transmission          0
# power                 0
# price                 0
# engineDisplacement    0
# date                  0
# location              0
# link                  0
# parse_date            0
# dtype: int64
